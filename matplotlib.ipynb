# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
x=np.linspace(0,10,100)
y=np.sin(x)
y2 = np.cos(x)
y2
# Out:
# array([ 1.        ,  0.99490282,  0.97966323,  0.95443659,  0.91948007,
#         0.87515004,  0.8218984 ,  0.76026803,  0.69088721,  0.61446323,
#         0.53177518,  0.44366602,  0.35103397,  0.25482335,  0.15601496,
#         0.0556161 , -0.04534973, -0.14585325, -0.24486989, -0.34139023,
#        -0.43443032, -0.52304166, -0.60632092, -0.68341913, -0.75355031,
#        -0.81599952, -0.87013012, -0.91539031, -0.95131866, -0.97754893,
#        -0.9938137 , -0.99994717, -0.9958868 , -0.981674  , -0.95745366,
#        -0.92347268, -0.88007748, -0.82771044, -0.76690542, -0.69828229,
#        -0.6225406 , -0.54045251, -0.45285485, -0.36064061, -0.26474988,
#        -0.16616018, -0.06587659,  0.03507857,  0.13567613,  0.23489055,
#         0.33171042,  0.4251487 ,  0.51425287,  0.59811455,  0.67587883,
#         0.74675295,  0.8100144 ,  0.86501827,  0.91120382,  0.94810022,
#         0.97533134,  0.99261957,  0.99978867,  0.99676556,  0.98358105,
#         0.96036956,  0.9273677 ,  0.88491192,  0.83343502,  0.77346177,
#         0.70560358,  0.63055219,  0.54907273,  0.46199582,  0.37020915,
#         0.27464844,  0.17628785,  0.07613012, -0.0248037 , -0.12548467,
#        -0.2248864 , -0.32199555, -0.41582217, -0.50540974, -0.58984498,
#        -0.66826712, -0.7398767 , -0.8039437 , -0.859815  , -0.90692104,
#        -0.94478159, -0.97301068, -0.99132055, -0.99952453, -0.99753899,
#        -0.98538417, -0.96318398, -0.93116473, -0.88965286, -0.83907153])

# %%
plt.plot(x,y)

# %%
plt.plot(x, y, color='red')
plt.title("Sine Wave Trending Line", fontsize=14)
plt.ylabel("Y Axis")
plt.xlabel("X Axis")
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.plot(x, y2, color='blue', label="cos wave line")
plt.plot(x, y, color='red', label="sine wave line")
plt.title("Cos & Sine Wave Trending Lines", fontsize=14)
plt.ylabel("Y Axis")
plt.xlabel("X Axis")
plt.legend()
plt.savefig('chart1.png')
plt.show()

# %%
## Bar Chart

categories = ['A', 'B', 'C', 'D']
values = [5, 7, 3, 8]

# %%
colors = ('blue', 'red', 'green', 'purple')
plt.bar(categories, values, width=0.6, color=colors, alpha=0.7)
plt.title("Sales Bar Chart")
plt.xlabel("Categories")
plt.ylabel("Sales in Millions $")
# plt.grid(axis='y', linestyle='--')
plt.show()

# %%
colors = ('blue', 'red', 'green', 'purple')
plt.barh(categories, values, color=colors, alpha=0.5)
plt.title("Sales Bar Chart")
plt.xlabel("Categories")
plt.ylabel("Sales in Millions $")
# plt.grid(axis='y', linestyle='--')
plt.show()

# %%
data = np.random.randn(1000)
data
# Out:
# array([-1.50989001e+00, -1.40638645e+00,  1.84076366e+00, -4.13338629e-01,
#        -1.27395312e+00,  2.59586831e+00, -1.18838118e+00, -1.69431322e+00,
#        -4.66735967e-01, -4.39417160e-01,  1.08685530e+00,  6.84771800e-01,
#         5.04486519e-01, -1.08868891e+00, -1.24808804e+00,  1.19460999e+00,
#         1.04655699e+00, -3.72833785e-01, -6.99208046e-01, -2.95876668e-01,
#         1.86647198e+00,  1.13428045e+00, -2.37545805e-01, -2.23151514e-01,
#         1.02242028e+00, -6.80717991e-01, -3.92542393e-01, -6.01778706e-01,
#        -1.61351463e+00, -1.04198539e+00, -9.68396919e-01,  8.86261151e-01,
#         4.77186770e-03, -6.19802293e-01,  1.29108172e+00,  5.99290965e-01,
#        -5.02559355e-01,  3.87661895e-01, -7.19974745e-01, -2.73730322e-01,
#        -5.99384004e-01,  4.75508635e-01,  2.39009785e-02, -5.08309807e-01,
#        -1.22070523e+00,  1.21632698e+00, -2.52958030e-01, -5.37598801e-01,
#         1.56831517e+00,  1.74178026e+00,  2.42731654e+00,  9.27218825e-01,
#         5.48146124e-01,  3.27735559e-01,  6.01244805e-01, -3.63553476e-01,
#         9.65733915e-01,  9.87241465e-01,  1.18506531e+00, -6.43730458e-01,
#         1.91292349e+00,  2.48463770e+00,  5.18503230e-01,  2.36374003e-01,
#        -9.72944371e-01,  4.07027925e-01,  1.79931982e+00, -1.10877780e+00,
#         6.87149434e-01, -1.36303047e+00,  1.25485383e-01, -7.07566386e-01,
#        -1.00668021e+00,  1.02391238e+00, -6.23151084e-01,  1.70890481e+00,
#         9.97020375e-01,  5.87488915e-01,  2.66244334e-02,  7.66014520e-01,
#         8.95827610e-01,  1.24842182e+00,  1.50894185e+00, -9.22117774e-01,
#         1.33135136e+00,  1.02200862e+00, -2.68629589e-01,  1.44120201e+00,
#         1.51776729e-01, -3.61666846e-01,  1.62262479e+00,  6.50020523e-01,
#         1.86303031e-01,  6.46757145e-01, -1.34879773e+00,  2.89048386e-01,
#         3.29975513e-01, -7.12735146e-02, -7.43139918e-01,  7.61205508e-01,
#        -8.52742179e-01, -1.88493460e-01, -8.56454043e-01, -1.65900462e+00,
#        -6.84196421e-01,  1.16152441e-01, -6.18075196e-01,  8.34639186e-01,
#        -5.94773471e-01, -5.52084407e-02, -1.10685943e+00,  2.52701606e-01,
#        -7.61188267e-01, -1.38834115e+00, -2.09891044e+00,  8.94135523e-01,
#        -1.84080400e+00,  1.31132007e+00,  7.56057067e-01, -4.39149556e-01])

# %%
plt.hist(data, bins=20, color='blue' , alpha=0.5)
plt.title("Sample Data Distribution")
plt.xlabel("X label")
plt.ylabel("Y Label")
plt.show()

# %%
data = np.random.randn(1000)

# %%
# Exercise Task

# Exercise 1: Sales Trend Analysis
# Objective: Analyze monthly sales data to identify trends.

#Customization:
#Add title, axis labels, and markers, show legend

months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
sales = [4500, 4800, 5000, 4700, 6300, 5300, 4600, 4800, 6000, 5200, 6100, 5400]

# %%
plt.figure(figsize=(10, 5))
plt.plot(months, sales, color='green', marker='o', label='Trend Lines')
plt.title("Monthly Sales Trends")
plt.xlabel("Months")
plt.ylabel("Sales in $")
plt.legend()
plt.show()

# %%
categories = ['Electronics', 'Furniture', 'Clothing', 'Books']
sales = [10000, 7000, 8000, 5000]

# %%
plt.bar(categories, values, width=0.6, color=colors, alpha=0.7)
plt.title("Sales Bar Chart")
plt.xlabel("Categories")
plt.ylabel("Sales in Millions $")
# plt.grid(axis='y', linestyle='--')
plt.savefig('bar.png')
plt.show()

# %%
#Exercise 3: Customer Age Distribution

#Objective: Visualize the distribution of customer ages using a histogram.

#Task: Create a histogram of ages with 10 bins.
#Customization:
#Add gridlines for better visualization.
#Customize color and transparency.

# %%
#random age
ages = np.random.randint(18, 65, 500)  # 500 random ages between 18 and 65
ages
# Out:
# array([48, 53, 49, 50, 59, 39, 36, 35, 30, 57, 23, 41, 37, 59, 23, 25, 35,
#        62, 58, 36, 27, 37, 37, 58, 36, 57, 20, 19, 40, 63, 27, 61, 64, 26,
#        34, 23, 54, 32, 52, 44, 46, 61, 24, 21, 57, 29, 60, 38, 29, 34, 43,
#        40, 26, 28, 43, 48, 24, 38, 64, 27, 44, 59, 30, 48, 58, 37, 61, 53,
#        37, 59, 54, 49, 52, 55, 46, 51, 18, 33, 59, 50, 64, 60, 43, 19, 29,
#        20, 21, 44, 30, 40, 52, 43, 49, 31, 48, 25, 24, 25, 50, 50, 46, 64,
#        37, 30, 19, 46, 45, 38, 37, 37, 59, 51, 42, 25, 34, 32, 42, 53, 27,
#        59, 43, 29, 46, 46, 24, 30, 44, 27, 18, 36, 31, 35, 28, 19, 31, 50,
#        27, 49, 54, 54, 47, 54, 57, 57, 56, 35, 42, 63, 57, 49, 25, 60, 32,
#        55, 43, 43, 59, 37, 41, 23, 28, 18, 54, 19, 47, 45, 63, 26, 56, 46,
#        24, 61, 40, 62, 30, 62, 55, 51, 52, 61, 37, 54, 25, 60, 28, 44, 39,
#        58, 37, 36, 36, 39, 54, 48, 23, 30, 47, 40, 58, 44, 46, 38, 29, 51,
#        48, 49, 25, 22, 40, 64, 21, 46, 22, 37, 64, 28, 52, 18, 57, 53, 34,
#        63, 28, 29, 27, 43, 45, 30, 63, 28, 25, 54, 44, 61, 52, 41, 62, 62,
#        60, 53, 25, 27, 32, 62, 34, 64, 31, 38, 19, 51, 18, 51, 26, 30, 54,
#        34, 51, 35, 35, 56, 44, 45, 31, 58, 37, 28, 25, 25, 64, 28, 29, 36,
#        35, 24, 63, 35, 48, 19, 45, 55, 38, 26, 35, 36, 51, 32, 28, 60, 57,
#        35, 41, 18, 46, 61, 18, 22, 25, 23, 48, 19, 41, 49, 50, 52, 62, 45,
#        56, 41, 47, 60, 59, 24, 37, 39, 59, 49, 48, 63, 21, 47, 60, 19, 36,
#        52, 42, 37, 37, 50, 29, 54, 57, 34, 39, 27, 40, 41, 59, 60, 51, 62,
#        38, 24, 58, 30, 42, 35, 29, 60, 48, 49, 48, 38, 60, 29, 52, 44, 33,
#        29, 43, 30, 42, 61, 34, 26, 35, 52, 43, 36, 41, 23, 27, 34, 42, 37,
#        44, 51, 48, 55, 61, 52, 24, 22, 33, 38, 64, 61, 63, 52, 32, 58, 35,
#        37, 24, 52, 49, 37, 56, 47, 58, 53, 18, 53, 41, 58, 28, 57, 26, 33,
#        21, 54, 38, 31, 38, 47, 60, 43, 34, 41, 18, 55, 48, 44, 20, 18, 57,
#        28, 30, 61, 48, 39, 31, 43, 20, 59, 33, 32, 31, 47, 41, 56, 22, 22,
#        19, 60, 39, 36, 26, 54, 43, 50, 27, 28, 35, 27, 19, 57, 33, 56, 58,
#        56, 32, 40, 21, 36, 22, 23, 33, 37, 44, 19, 36, 34, 35, 45, 64, 44,
#        52, 62, 53, 21, 52, 36, 19, 53, 21, 56, 54, 57, 29, 40, 47, 29, 25,
#        56, 35, 42, 51, 60, 36, 59])

# %%
plt.hist(ages, bins=10, color='red' , alpha=0.7)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Age bins")
plt.show()

# %%
#Exercise 4: Regional Sales Performance (Pie Chart)

#Objective: Visualize the percentage contribution of each region to total sales.

#Task: Create a pie chart showing sales contribution by region. Customization: Explode the region with the highest sales. Add percentage #labels on each slice.

# %%
regions = ['North', 'South', 'East', 'West']
sales = [3000, 4000, 2200, 1500]

# %%
colors = ('red', 'skyblue', 'green', 'purple')
explodes = (0, 0.1, 0, 0)
plt.pie(sales, labels=regions, autopct='%1.2f%%', colors=colors, explode=explodes, shadow=True)
plt.savefig('pie.png')

# %%
#Exercise 5: Sales Forecast Visualization (Shaded Area Plot)

#Objective: Visualize historical sales along with forecasted values using an area plot.

#Task: Create an area plot showing actual vs. forecasted sales. Customization: Use different colors for actual and forecasted values. Add #hatching patterns for the forecasted area.

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']
sales = [5000, 5200, 5400, 5300, 5500, 5700]
forecast = [5800, 5900, 6000, 6100, 6200, 6300]

# %%
plt.figure(figsize=(10,6))

plt.fill_between(months, forecast, label='Forcasting Sales', color='lightgreen', alpha=0.7, hatch='/')
plt.fill_between(months, sales, label='Actual Sales', color='skyblue', alpha=0.5)

plt.title("Actual vs Forcasted sales in $")
plt.ylabel("In Millions $")
plt.xlabel("Months")
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.legend(loc='upper right')

plt.show()

# %%
#Final Task: Correlation between Sales and Advertisement Spend

#Objective: Explore the relationship between sales and advertising spend using a scatter plot.

#Task: Create a scatter plot of sales vs. ad spend.
#Customization:
#Add a trendline.
#Customize marker size and color based on ad spend.

# %%
ad_spend = [1000, 1500, 1800, 2000, 2300, 2500, 3000, 3200]
sales = [4000, 4500, 5000, 5200, 5800, 6000, 6400, 7000]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data: Advertisement Spend and Sales
ad_spend = [1000, 1500, 1800, 2000, 2300, 2500, 3000, 3200]
sales = [4000, 4500, 5000, 5200, 5800, 6000, 6400, 7000]

# Create the scatter plot
plt.figure(figsize=(8, 6))
sc = plt.scatter(ad_spend, sales, 
                 c=ad_spend, cmap='cool',  # Color based on ad spend
                 s=[spend / 10 for spend in ad_spend],  # Marker size based on ad spend
                 alpha=0.7, edgecolor='black')

# Add a trendline
z = np.polyfit(ad_spend, sales, 1)  # Linear regression
p = np.poly1d(z)
plt.plot(ad_spend, p(ad_spend), linestyle='--', color='red', label='Trendline')

# Customize the plot
plt.title('Sales vs Advertisement Spend', fontsize=16)
plt.xlabel('Advertisement Spend ($)', fontsize=12)
plt.ylabel('Sales ($)', fontsize=12)
plt.colorbar(sc, label='Ad Spend')  # Add color legend
plt.legend()

# Display the plot
plt.savefig('test1.png')
plt.show()
